# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("prices.csv")
df
# Out:
#     Area  Bedroom  Age   Price
# 0   2600      3.0   20  550000
# 1   3000      4.0   15  565000
# 2   3200      3.0   18  610000
# 3   3600      3.0   30  595000
# 4   4000      5.0    8  760000
# 5   2800      3.0   12  590000
# 6   3400      4.0   10  650000
# 7   3300      3.0   25  605000
# 8   4100      5.0    5  780000
# 9   2900      3.0   20  570000
# 10  3700      4.0   18  640000
# 11  4200      5.0    7  790000
# 12  3100      3.0   22  600000
# 13  3050      3.0   12  595000
# 14  3900      4.0   10  710000
# 15  3600      3.0   15  620000
# 16  2800      2.0   25  520000
# 17  4300      5.0    3  820000
# 18  2700      3.0   20  555000
# 19  3500      4.0   14  660000
# 20  3000      NaN   16  560000
# 21  3200      NaN   20  600000
# 22  3400      4.0   12  645000
# 23  3600      NaN   28  610000
# 24  3800      4.0    9  700000
# 25  4000      NaN    6  755000
# 26  4200      5.0    4  790000
# 27  4400      5.0    3  830000
# 28  4600      4.0    7  850000
# 29  4800      5.0    2  880000
# 30  5000      NaN    5  900000
# 31  2700      3.0   21  550000
# 32  2850      2.0   18  540000
# 33  2950      3.0   19  570000
# 34  3100      4.0   15  600000
# 35  3250      NaN   17  610000
# 36  3450      4.0   14  650000
# 37  3550      3.0   10  630000
# 38  3650      4.0   11  645000
# 39  3750      3.0   12  670000
# 40  3850      4.0    8  695000
# 41  3950      5.0    6  720000
# 42  4050      5.0    5  750000
# 43  4150      5.0    3  780000
# 44  4250      5.0    4  810000
# 45  4350      4.0    2  835000
# 46  4450      3.0    9  710000
# 47  4550      4.0    7  740000
# 48  4650      5.0    6  770000
# 49  4750      4.0    8  790000
# 50  4850      5.0    3  820000

# %%
import math
median_bedroom= math.floor(df.Bedroom.median())
median_bedroom
# Out:
# 4

# %%
df.Bedroom= df.Bedroom.fillna(median_bedroom)
df
# Out:
#     Area  Bedroom  Age   Price
# 0   2600      3.0   20  550000
# 1   3000      4.0   15  565000
# 2   3200      3.0   18  610000
# 3   3600      3.0   30  595000
# 4   4000      5.0    8  760000
# 5   2800      3.0   12  590000
# 6   3400      4.0   10  650000
# 7   3300      3.0   25  605000
# 8   4100      5.0    5  780000
# 9   2900      3.0   20  570000
# 10  3700      4.0   18  640000
# 11  4200      5.0    7  790000
# 12  3100      3.0   22  600000
# 13  3050      3.0   12  595000
# 14  3900      4.0   10  710000
# 15  3600      3.0   15  620000
# 16  2800      2.0   25  520000
# 17  4300      5.0    3  820000
# 18  2700      3.0   20  555000
# 19  3500      4.0   14  660000
# 20  3000      4.0   16  560000
# 21  3200      4.0   20  600000
# 22  3400      4.0   12  645000
# 23  3600      4.0   28  610000
# 24  3800      4.0    9  700000
# 25  4000      4.0    6  755000
# 26  4200      5.0    4  790000
# 27  4400      5.0    3  830000
# 28  4600      4.0    7  850000
# 29  4800      5.0    2  880000
# 30  5000      4.0    5  900000
# 31  2700      3.0   21  550000
# 32  2850      2.0   18  540000
# 33  2950      3.0   19  570000
# 34  3100      4.0   15  600000
# 35  3250      4.0   17  610000
# 36  3450      4.0   14  650000
# 37  3550      3.0   10  630000
# 38  3650      4.0   11  645000
# 39  3750      3.0   12  670000
# 40  3850      4.0    8  695000
# 41  3950      5.0    6  720000
# 42  4050      5.0    5  750000
# 43  4150      5.0    3  780000
# 44  4250      5.0    4  810000
# 45  4350      4.0    2  835000
# 46  4450      3.0    9  710000
# 47  4550      4.0    7  740000
# 48  4650      5.0    6  770000
# 49  4750      4.0    8  790000
# 50  4850      5.0    3  820000

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['Area','Bedroom','Age']],df.Price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  104.96120636, 13334.31970524, -3802.57739956])

# %%
reg.intercept_
# Out:
# 287876.00565641304

# %%
reg.predict([[3000,3,40]])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([490659.48785572])

# %%
reg.predict([[1600,2,8]])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([452061.956039])

# %%
reg.predict([[4500,4,22]])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([729882.01028622])

# %%
X = df[['Area', 'Bedroom', 'Age']]
y = df['Price']
model = linear_model.LinearRegression()
model.fit(X, y)
plt.scatter(df['Area'], df['Price'], color='blue', label='Actual Data')
plt.xlabel('Area (sq.ft)')
plt.ylabel('Price')
plt.title('Linear Regression: Area vs Price')
plt.legend()
plt.show()

# %%
model.score(X, y)
# Out:
# 0.9390854480883942
